# %% [markdown]
# <a href="https://colab.research.google.com/github/hyemin0408/2025-1-myclass-BDA/blob/main/inclass/02w_B_0312_pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

s = ['희빈', '수영', '현수', '지호', '지민']
p = pd.Series([99, 84, 92, 65, 78], index=s)
p
# Out:
# 희빈    99
# 수영    84
# 현수    92
# 지호    65
# 지민    78
# dtype: int64

# %% [markdown]
# ## 시리즈의 기본 통계 함수

# %%
p.name = '수학 성적'
p.index.name = '이름'
p
# Out:
# 이름
# 희빈    99
# 수영    84
# 현수    92
# 지호    65
# 지민    78
# Name: 수학 성적, dtype: int64

# %%
p.sort_values()
# Out:
# 이름
# 지호    65
# 지민    78
# 수영    84
# 현수    92
# 희빈    99
# Name: 수학 성적, dtype: int64

# %% [markdown]
# ##데이터프레임 다루기

# %%
import pandas as pd
df = pd.DataFrame([10, 20, 30, 40, 50])
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
list('abc')

# %%
df = pd.DataFrame([[1, 2, 3],[10, 20, 30], [100, 200, 300]], index=list('abc'))
df
# Out:
#      0    1    2
# a    1    2    3
# b   10   20   30
# c  100  200  300

# %%
df.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1 = pd.DataFrame(np.random.randint(1, 46, (5, 6)))
df1
# Out:
#     0   1   2   3   4   5
# 0  18  26  41   8  25  35
# 1  24  17  19  28  22  37
# 2  28  38  22   3   4  38
# 3  11  25  31   1  20  22
# 4  45  29  38  20  20  37

# %%
df1 = pd.DataFrame(np.random.random((5, 3)))
df1
# Out:
#           0         1         2
# 0  0.537576  0.862108  0.819665
# 1  0.953148  0.482625  0.922767
# 2  0.859888  0.058582  0.573566
# 3  0.796479  0.535166  0.017728
# 4  0.896465  0.781207  0.261531

# %%
df = pd.DataFrame({'numbers': [1, 2, 3],
                  'colors':['red','white','blue']})
df
# Out:
#    numbers colors
# 0        1    red
# 1        2  white
# 2        3   blue

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['numbers', 'colors'], dtype='object')

# %%
import pandas as pd

df = pd.DataFrame({'국어': [82, 76, 67], '수학': [99, 87, 78]},
                  index= ['김국진', '신영희', '이길순'])
df
# Out:
#      국어  수학
# 김국진  82  99
# 신영희  76  87
# 이길순  67  78

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd


df = pd.DataFrame([
    {'국어': 70, '수학': 80, '영어': 90},
    {'국어': 80, '영어': 99},
    {'수학': 66, '영어': 78}
])

df
# Out:
#      국어    수학  영어
# 0  70.0  80.0  90
# 1  80.0   NaN  99
# 2   NaN  66.0  78

# %% [markdown]
# ## 데이터프레임 참조

# %%
import pandas as pd

pf = pd.DataFrame(data =[[25,35,8,18],
                        [18,27,10,20],
                        [17,17,10,19],
                        [12,22,9,20],
                        [22,24,8,16]],
               index=['윤일형','김수희', '홍소희', '유한빈', '신수빈'],
               columns=['중간','기말','과제','출석'])
pf
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 김수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20
# 신수빈  22  24   8  16

# %%
pf
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 김수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20
# 신수빈  22  24   8  16

# %%
pf.loc['김수희','기말']
# Out:
# 27

# %%
pf.loc['윤일형':'유한빈', '기말':'과제']
# Out:
#      기말  과제
# 윤일형  35   8
# 김수희  27  10
# 홍소희  17  10
# 유한빈  22   9

# %%
pf.index
# Out:
# Index(['윤일형', '김수희', '홍소희', '유한빈', '신수빈'], dtype='object')

# %%
pf.columns
# Out:
# Index(['중간', '기말', '과제', '출석'], dtype='object')

# %%
pf.at['윤일형','과제']
# Out:
# 8

# %%
pf.at['윤일형','기말']
# Out:
# 35

# %%
pf.at[pf.index[1],'출석']
# Out:
# 20

# %% [markdown]
# ## 종료
