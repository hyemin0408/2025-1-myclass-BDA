# %% [markdown]
# <a href="https://colab.research.google.com/github/hyemin0408/2025-1-myclass-BDA/blob/main/inclass/07w_B_web_0416_easy_ch07_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 단원 07 데이터 정제

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'sex'   : ['M', 'F', np.nan, 'M', 'F'],
                   'score' : [5, 4, 3, 4, None]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %%
pd.isna(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
pd.isnull(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
pd.isna(df).sum()
# Out:
# sex      1
# score    1
# dtype: int64

# %%
pd.isna(df).sum(axis=1)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# dtype: int64

# %%
pd.isna(df).sum(axis=0)
# Out:
# sex      1
# score    1
# dtype: int64

# %%
s = pd.Series([True, False, True])
s
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
s.sum()
# Out:
# np.int64(2)

# %%
s.any()
# Out:
# np.True_

# %%
s.all()
# Out:
# np.False_

# %%
df.isnull()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isnull().any()
# Out:
# sex      True
# score    True
# dtype: bool

# %%
df.notnull()
# Out:
#      sex  score
# 0   True   True
# 1   True   True
# 2  False   True
# 3   True   True
# 4   True  False

# %%
df.isnull().all()
# Out:
# sex      False
# score    False
# dtype: bool

# %%
df.isnull().any()
# Out:
# sex      True
# score    True
# dtype: bool

# %%
df.isna().any(axis=1)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
~df.isna().any(axis=1)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
df[df.isna().any(axis=1)]
# Out:
#    sex  score
# 2  NaN    3.0
# 4    F    NaN

# %%
df[~df.isna().any(axis=1)]
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %% [markdown]
# ## 결측 값 시각화

# %%
import seaborn as sns

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
import missingno as msno
msno.matrix(df);

# %%
tdf = sns.load_dataset('titanic')
sns.heatmap(tdf.isnull(), cbar=False);

# %%
msno.matrix( tdf[tdf.isna().sum(axis=1) == 1] );

# %%
tdf[tdf.embarked.isna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
msno.heatmap(tdf)
# Out:
# <Axes: >
